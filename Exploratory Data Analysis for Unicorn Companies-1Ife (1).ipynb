# %%
# import the necessary libraries
import numpy as np
import pandas as pd
import os
# for visuals
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load and read data file
'''inside the quotation is a filepath of the data file'''
Unicorn = pd.read_csv(r'C:\\Users\\OLUBUNMI\\Downloads\\Unicorn Companies Dataset-20230713T175752Z-001\\Unicorn Companies Dataset\\Unicorn_Companies.csv') # for csv file # pd.read_excel(r'') ===> for excel file format
Unicorn
# Out:
#           Company Valuation Date Joined                         Industry  \
# 0       Bytedance     $180B  2017-04-07          Artificial intelligence
# 1          SpaceX     $100B  2012-12-01                            Other
# 2           SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe      $95B  2014-01-23                          Fintech
# 4          Klarna      $46B  2011-12-12                          Fintech
# ...           ...       ...         ...                              ...
# 1069     Zhaogang       $1B  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan       $1B  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo       $1B  2021-05-06                Consumer & retail
# 1072         Zopa       $1B  2021-10-19                          Fintech
# 1073        Zwift       $1B  2020-09-16  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded Funding  \
# ...

# %%
# check the first 5 rows
Unicorn.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B  2017-04-07          Artificial intelligence
# 1     SpaceX     $100B  2012-12-01                            Other
# 2      SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe      $95B  2014-01-23                          Fintech
# 4     Klarna      $46B  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# ...

# %%
# check the last 5 rows
Unicorn.tail()
# Out:
#           Company Valuation Date Joined                         Industry  \
# 1069     Zhaogang       $1B  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan       $1B  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo       $1B  2021-05-06                Consumer & retail
# 1072         Zopa       $1B  2021-10-19                          Fintech
# 1073        Zwift       $1B  2020-09-16  E-commerce & direct-to-consumer
#
#             City         Country      Continent  Year Founded Funding  \
# 1069    Shanghai           China           Asia          2012   $379M
# 1070     Beijing           China           Asia          2015   $990M
# 1071   Chongqing           China           Asia          2018    $80M
# 1072      London  United Kingdom         Europe          2005   $792M
# 1073  Long Beach   United States  North America          2014   $620M
#
#                                        Select Investors
# ...

# %% [markdown]
# ## Data Inspection and Manipulation

# %%
# check the shape of the data
Unicorn.shape
# Out:
# (1074, 10)

# %%
# check the columns
Unicorn.columns
# Out:
# Index(['Company', 'Valuation', 'Date Joined', 'Industry', 'City', 'Country',
#        'Continent', 'Year Founded', 'Funding', 'Select Investors'],
#       dtype='object')

# %%
# check the data types
Unicorn.dtypes
# Out:
# Company             object
# Valuation           object
# Date Joined         object
# Industry            object
# City                object
# Country             object
# Continent           object
# Year Founded         int64
# Funding             object
# Select Investors    object
# dtype: object

# %%
# check for information about the data
Unicorn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country           1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 84.0+ KB

# %%
# check for missing values values
Unicorn.isnull()
# Out:
#       Company  Valuation  Date Joined  Industry   City  Country  Continent  \
# 0       False      False        False     False  False    False      False
# 1       False      False        False     False  False    False      False
# 2       False      False        False     False  False    False      False
# 3       False      False        False     False  False    False      False
# 4       False      False        False     False  False    False      False
# ...       ...        ...          ...       ...    ...      ...        ...
# 1069    False      False        False     False  False    False      False
# 1070    False      False        False     False  False    False      False
# 1071    False      False        False     False  False    False      False
# 1072    False      False        False     False  False    False      False
# 1073    False      False        False     False  False    False      False
#
#       Year Founded  Funding  Select Investors
# ...

# %%
# check all the columns with missing value/character
Unicorn.isnull().sum()
# Out:
# Company              0
# Valuation            0
# Date Joined          0
# Industry             0
# City                16
# Country              0
# Continent            0
# Year Founded         0
# Funding              0
# Select Investors     1
# dtype: int64

# %%
# visualize the missing values
plt.figure(figsize = (10,5))
plt.title('visualizing missing values')
sns.heatmap(Unicorn.isnull(), cbar = True, cmap = 'magma_r')
plt.show()

# %% [markdown]
# ### Observation
# #### We can observe from the above visualization that our missing values is way more than one, hence the colour and the lines indicating the column where we have the missing values which is the City column.
# #### Its also showing us which rows these missing values are.

# %%
# check for missing objects in City column
Unicorn[Unicorn.City.isnull()]
# Out:
#                          Company Valuation Date Joined  \
# 12                           FTX      $32B  2021-07-20
# 170                    HyalRoute       $4B  2020-05-26
# 242                       Moglix       $3B  2021-05-17
# 251                         Trax       $3B  2019-07-22
# 325                  Amber Group       $3B  2021-06-21
# 382                    Ninja Van       $2B  2021-09-27
# 541   Advance Intelligence Group       $2B  2021-09-23
# 811                    Carousell       $1B  2021-09-15
# 848                   Matrixport       $1B  2021-06-01
# 880                     bolttech       $1B  2021-07-01
# 889                        Carro       $1B  2021-06-14
# 893                        Cider       $1B  2021-09-02
# 980                         NIUM       $1B  2021-07-13
# 986                          ONE       $1B  2021-12-08
# 994                      PatSnap       $1B  2021-03-16
# 1061                       WeLab       $1B  2017-11-08
#
# ...

# %%
# How many Companies have no Cities
len(Unicorn[Unicorn.City.isnull()].Company.unique())
# Out:
# 16

# %%
# What companies have countries with no cities and how many records are affected
Unicorn[Unicorn.City.isnull()].Company.value_counts()
# Out:
# FTX                           1
# HyalRoute                     1
# Moglix                        1
# Trax                          1
# Amber Group                   1
# Ninja Van                     1
# Advance Intelligence Group    1
# Carousell                     1
# Matrixport                    1
# bolttech                      1
# Carro                         1
# Cider                         1
# NIUM                          1
# ONE                           1
# PatSnap                       1
# WeLab                         1
# Name: Company, dtype: int64

# %%
# Number of rows with missing cities which is the Percentage. First, we define:
num_missing = Unicorn[Unicorn.City.isnull()].shape[0]

# number of rows in all the dataset
num_all = Unicorn.shape[0]

# percentage of rows with missing cities
round((num_missing / num_all) * 100, 2)
# Out:
# 1.49

# %% [markdown]
# #### Observation
# ##### Only 1.5% of data is missing in the City column

# %% [markdown]
# ### Replace NaN(missing value) in the City column to 'Unidentified'

# %%
Unicorn.City.value_counts()
# Out:
# San Francisco    152
# New York         103
# Beijing           63
# Shanghai          44
# London            34
#                 ...
# Santa Barbara      1
# Altrincham         1
# Northbrook         1
# Cincinnati         1
# Milpitas           1
# Name: City, Length: 256, dtype: int64

# %%
# to check if Cty is all in string
Unicorn.dtypes
# Out:
# Company             object
# Valuation           object
# Date Joined         object
# Industry            object
# City                object
# Country             object
# Continent           object
# Year Founded         int64
# Funding             object
# Select Investors    object
# dtype: object

# %%
import pandas as pd

# Read in your dataframe
Unicorn = pd.read_csv(r'C:\\Users\\OLUBUNMI\\Downloads\\Unicorn Companies Dataset-20230713T175752Z-001\\Unicorn Companies Dataset\\Unicorn_Companies.csv')

# Replace NaN values in City column with 'Unidentified'
Unicorn['City'].fillna('Unidentified', inplace=True)

# Print the updated dataframe
print(Unicorn)
# Out:
#           Company Valuation Date Joined                         Industry  \
# 0       Bytedance     $180B  2017-04-07          Artificial intelligence
# 1          SpaceX     $100B  2012-12-01                            Other
# 2           SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe      $95B  2014-01-23                          Fintech
# 4          Klarna      $46B  2011-12-12                          Fintech
# ...           ...       ...         ...                              ...
# 1069     Zhaogang       $1B  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan       $1B  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo       $1B  2021-05-06                Consumer & retail
# 1072         Zopa       $1B  2021-10-19                          Fintech
# 1073        Zwift       $1B  2020-09-16  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded Funding  \
# ...

# %%
# check if we still have 'Unidentified'
Unicorn[Unicorn.City == 'Unidentified']
# Out:
#                          Company Valuation Date Joined  \
# 12                           FTX      $32B  2021-07-20
# 170                    HyalRoute       $4B  2020-05-26
# 242                       Moglix       $3B  2021-05-17
# 251                         Trax       $3B  2019-07-22
# 325                  Amber Group       $3B  2021-06-21
# 382                    Ninja Van       $2B  2021-09-27
# 541   Advance Intelligence Group       $2B  2021-09-23
# 811                    Carousell       $1B  2021-09-15
# 848                   Matrixport       $1B  2021-06-01
# 880                     bolttech       $1B  2021-07-01
# 889                        Carro       $1B  2021-06-14
# 893                        Cider       $1B  2021-09-02
# 980                         NIUM       $1B  2021-07-13
# 986                          ONE       $1B  2021-12-08
# 994                      PatSnap       $1B  2021-03-16
# 1061                       WeLab       $1B  2017-11-08
#
# ...

# %%
# Count the number of 'Unidentified' values in City column
num_unidentified = Unicorn['City'].value_counts()['Unidentified']

# Print the number of 'Unidentified' values
print(f"Number of 'Unidentified' values in City column: {num_unidentified}")
# Out:
# Number of 'Unidentified' values in City column: 16

# %%
#check for missing object in Select investor column
Unicorn[Unicorn['Select Investors'].isnull()]
# Out:
#               Company Valuation Date Joined                     Industry  \
# 629  LinkSure Network       $1B  2015-01-01  Mobile & telecommunications
#
#          City Country Continent  Year Founded Funding Select Investors
# 629  Shanghai   China      Asia          2013    $52M              NaN

# %%
# How many unique Companies have no select investors
len(Unicorn[Unicorn['Select Investors'].isnull()].Company.unique())
# Out:
# 1

# %%
# Replace NaN values in Select Investors column with 'Unidentified'
Unicorn['Select Investors'].fillna('Unidentified', inplace=True)

# Print the updated dataframe
print(Unicorn)
# Out:
#           Company Valuation Date Joined                         Industry  \
# 0       Bytedance     $180B  2017-04-07          Artificial intelligence
# 1          SpaceX     $100B  2012-12-01                            Other
# 2           SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe      $95B  2014-01-23                          Fintech
# 4          Klarna      $46B  2011-12-12                          Fintech
# ...           ...       ...         ...                              ...
# 1069     Zhaogang       $1B  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan       $1B  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo       $1B  2021-05-06                Consumer & retail
# 1072         Zopa       $1B  2021-10-19                          Fintech
# 1073        Zwift       $1B  2020-09-16  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded Funding  \
# ...

# %%
# check if we still have 'Unidentified'
Unicorn[Unicorn['Select Investors'] == 'Unidentified']
# Out:
#               Company Valuation Date Joined                     Industry  \
# 629  LinkSure Network       $1B  2015-01-01  Mobile & telecommunications
#
#          City Country Continent  Year Founded Funding Select Investors
# 629  Shanghai   China      Asia          2013    $52M     Unidentified

# %%
# view the summary statistics of the dataset
Unicorn.describe()
# Out:
#        Year Founded
# count   1074.000000
# mean    2012.895717
# std        5.698573
# min     1919.000000
# 25%     2011.000000
# 50%     2014.000000
# 75%     2016.000000
# max     2021.000000

# %%
Unicorn.dtypes
# Out:
# Company             object
# Valuation           object
# Date Joined         object
# Industry            object
# City                object
# Country             object
# Continent           object
# Year Founded         int64
# Funding             object
# Select Investors    object
# dtype: object

# %%
# Convert Date column to datetime format
Unicorn['Date Joined'] = pd.to_datetime(Unicorn['Date Joined'])

# Print the updated dataframe with Date column in datetime format
print(Unicorn)
# Out:
#           Company Valuation Date Joined                         Industry  \
# 0       Bytedance     $180B  2017-04-07          Artificial intelligence
# 1          SpaceX     $100B  2012-12-01                            Other
# 2           SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe      $95B  2014-01-23                          Fintech
# 4          Klarna      $46B  2011-12-12                          Fintech
# ...           ...       ...         ...                              ...
# 1069     Zhaogang       $1B  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan       $1B  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo       $1B  2021-05-06                Consumer & retail
# 1072         Zopa       $1B  2021-10-19                          Fintech
# 1073        Zwift       $1B  2020-09-16  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded Funding  \
# ...

# %%
Unicorn.dtypes
# Out:
# Company                     object
# Valuation                   object
# Date Joined         datetime64[ns]
# Industry                    object
# City                        object
# Country                     object
# Continent                   object
# Year Founded                 int64
# Funding                     object
# Select Investors            object
# dtype: object

# %%
Unicorn.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B  2017-04-07          Artificial intelligence
# 1     SpaceX     $100B  2012-12-01                            Other
# 2      SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe      $95B  2014-01-23                          Fintech
# 4     Klarna      $46B  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# ...

# %%
Unicorn.dtypes
# Out:
# Company                     object
# Valuation                   object
# Date Joined         datetime64[ns]
# Industry                    object
# City                        object
# Country                     object
# Continent                   object
# Year Founded                 int64
# Funding                     object
# Select Investors            object
# dtype: object

# %%
# Check value at position 215 in Funding column
print(Unicorn.iloc[215])
# Out:
# Company                                      SSENSE
# Valuation                                       $4B
# Date Joined                     2021-06-08 00:00:00
# Industry            E-commerce & direct-to-consumer
# City                                       Montreal
# Country                                      Canada
# Continent                             North America
# Year Founded                                   2003
# Funding                                     Unknown
# Select Investors                    Sequoia Capital
# Name: 215, dtype: object

# %%
# Replace empty strings with NaN values
Unicorn['Funding'] = Unicorn['Funding'].replace('Unknown', np.nan)

# %%
# Check value at position 215 in Funding column
print(Unicorn.iloc[215])
# Out:
# Company                                      SSENSE
# Valuation                                       $4B
# Date Joined                     2021-06-08 00:00:00
# Industry            E-commerce & direct-to-consumer
# City                                       Montreal
# Country                                      Canada
# Continent                             North America
# Year Founded                                   2003
# Funding                                         NaN
# Select Investors                    Sequoia Capital
# Name: 215, dtype: object

# %%
# check for more missing or unknown values in the funding column
Unicorn[Unicorn.Funding.isnull()]
# Out:
#               Company Valuation Date Joined  \
# 215            SSENSE       $4B  2021-06-08
# 424           Uplight       $2B  2021-03-03
# 567               ISN       $2B  2020-12-17
# 639        SITECH DEV       $1B  2019-05-16
# 651          Xiaobing       $1B  2021-07-12
# 717            Veepee       $1B  2007-07-02
# 733         DistroKid       $1B  2021-08-16
# 866          Assembly       $1B  2021-09-21
# 890      Carson Group       $1B  2021-07-14
# 945   Iodine Software       $1B  2021-12-01
# 947      Kendra Scott       $1B  2016-12-21
# 1002           Poizon       $1B  2019-04-29
#
#                                  Industry                   City  \
# 215       E-commerce & direct-to-consumer               Montreal
# 424                                 Other                Boulder
# 567   Supply chain, logistics, & delivery                 Dallas
# 639                                 Other                Guiyang
# ...

# %%
# Count the number of 'NaN' values in Funding column
# Count number of NaN values in 'Funding' column
num_funding_NaN = Unicorn['Funding'].isna().sum()

# Print number of NaN values in 'Funding' column
print(f"Number of NaN values in 'Funding' column: {num_funding_NaN}")
# Out:
# Number of NaN values in 'Funding' column: 12

# %%
# Replace all missing or unknown values in the funding column with'NaN'
# Convert all 0.0 values in 'Funding' column to NaN so that calculations can pass
Unicorn['Funding'].replace('0.0', np.nan, inplace=True)

# %%
# check if we now have all funding columns in 0.0 as NaN
Unicorn[Unicorn.Funding == '0.0']
# Out:
# Empty DataFrame
# Columns: [Company, Valuation, Date Joined, Industry, City, Country, Continent, Year Founded, Funding, Select Investors]
# Index: []

# %%
# Count the number of 'NaN' values in Valuation column
# Count number of NaN values in 'Valuation' column
num_Valuation_NaN = Unicorn['Valuation'].isna().sum()

# Print number of NaN values in 'Valuation' column
print(f"Number of NaN values in 'Valuation' column: {num_Valuation_NaN}")
# Out:
# Number of NaN values in 'Valuation' column: 0

# %%
Unicorn.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B  2017-04-07          Artificial intelligence
# 1     SpaceX     $100B  2012-12-01                            Other
# 2      SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe      $95B  2014-01-23                          Fintech
# 4     Klarna      $46B  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# ...

# %%
Unicorn.dtypes
# Out:
# Company                     object
# Valuation                   object
# Date Joined         datetime64[ns]
# Industry                    object
# City                        object
# Country                     object
# Continent                   object
# Year Founded                 int64
# Funding                     object
# Select Investors            object
# dtype: object

# %%
# Convert Valuation and Funding columns to numeric data type
Unicorn['Valuation'] = Unicorn['Valuation'].replace('[\$,]', '', regex=True).replace('[B]', 'e9', regex=True).replace('[M]', 'e6', regex=True).astype(float)
Unicorn['Funding'] = Unicorn['Funding'].replace('[\$,]', '', regex=True).replace('[B]', 'e9', regex=True).replace('[M]', 'e6', regex=True).astype(float)
Unicorn['Funding'] = Unicorn['Funding'].replace('[0.0]', 'NaN', regex=True).replace('[NaN]', '', regex=True).astype(float)

# %%
# check all the columns with missing value/character
Unicorn.isnull().sum()
# Out:
# Company              0
# Valuation            0
# Date Joined          0
# Industry             0
# City                 0
# Country              0
# Continent            0
# Year Founded         0
# Funding             12
# Select Investors     0
# dtype: int64

# %%
# check the data type
Unicorn.dtypes
# Out:
# Company                     object
# Valuation                  float64
# Date Joined         datetime64[ns]
# Industry                    object
# City                        object
# Country                     object
# Continent                   object
# Year Founded                 int64
# Funding                    float64
# Select Investors            object
# dtype: object

# %%
# Replace the Artificial intelligence in the Industry column with Artificial Intelligence
'''There is Artificial Intelligence and there is Artificial intelligence in the same column'''

Unicorn['Industry'].replace('Artificial intelligence', 'Artificial Intelligence', inplace=True)

# %% [markdown]
# ## Relationships and Insights
# - We will find all three(3) types of Analysis in this relationships and insights;
# 1 - Univariate Analysis
# 2 - Bivariate Analyis
# 3 - Multivariate Analysis

# %%
# # Calculate Return On Investment(ROI) as a percentage
Unicorn['ROI'] = ((Unicorn['Valuation'] - Unicorn['Funding']) / Unicorn['Funding']) * 100
Unicorn['ROI'] = Unicorn['ROI'].round(2)

# Print the result
print(Unicorn)
# Out:
#           Company     Valuation Date Joined                         Industry  \
# 0       Bytedance  1.800000e+11  2017-04-07          Artificial Intelligence
# 1          SpaceX  1.000000e+11  2012-12-01                            Other
# 2           SHEIN  1.000000e+11  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe  9.500000e+10  2014-01-23                          Fintech
# 4          Klarna  4.600000e+10  2011-12-12                          Fintech
# ...           ...           ...         ...                              ...
# 1069     Zhaogang  1.000000e+09  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan  1.000000e+09  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo  1.000000e+09  2021-05-06                Consumer & retail
# 1072         Zopa  1.000000e+09  2021-10-19                          Fintech
# 1073        Zwift  1.000000e+09  2020-09-16  E-commerce & direct-to-consumer
#
# ...

# %%
Unicorn.head()
# Out:
#      Company     Valuation Date Joined                         Industry  \
# 0  Bytedance  1.800000e+11  2017-04-07          Artificial Intelligence
# 1     SpaceX  1.000000e+11  2012-12-01                            Other
# 2      SHEIN  1.000000e+11  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe  9.500000e+10  2014-01-23                          Fintech
# 4     Klarna  4.600000e+10  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded       Funding  \
# 0        Beijing          China           Asia          2012  8.000000e+09
# 1      Hawthorne  United States  North America          2002  7.000000e+09
# 2       Shenzhen          China           Asia          2008  2.000000e+09
# 3  San Francisco  United States  North America          2010  2.000000e+09
# 4      Stockholm         Sweden         Europe          2005  4.000000e+09
#
#                                     Select Investors      ROI
# ...

# %%
Unicorn.tail()
# Out:
#           Company     Valuation Date Joined                         Industry  \
# 1069     Zhaogang  1.000000e+09  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan  1.000000e+09  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo  1.000000e+09  2021-05-06                Consumer & retail
# 1072         Zopa  1.000000e+09  2021-10-19                          Fintech
# 1073        Zwift  1.000000e+09  2020-09-16  E-commerce & direct-to-consumer
#
#             City         Country      Continent  Year Founded      Funding  \
# 1069    Shanghai           China           Asia          2012  379000000.0
# 1070     Beijing           China           Asia          2015  990000000.0
# 1071   Chongqing           China           Asia          2018   80000000.0
# 1072      London  United Kingdom         Europe          2005  792000000.0
# 1073  Long Beach   United States  North America          2014  620000000.0
#
# ...

# %%
# Top 10 Unicorn Companies by the ROI
top10_loc = Unicorn['ROI'].groupby(Unicorn['Company']).sum().head(10).sort_values(ascending = False)
top10_loc
# Out:
# Company
# 1047 Games           1474.80
# A24 Films            1233.33
# 6Sense               1073.71
# 1KMXC                1062.79
# 1Password             660.87
# 56PINGTAI             431.91
# ABL Space Systems     377.33
# 58 Daojia             233.33
# AIWAYS                152.53
# 4Paradigm             100.00
# Name: ROI, dtype: float64

# %%
# visualize using bar chart
ax = top10_loc.plot(kind = 'barh', figsize = (10, 5), title = 'Top 10 Companies by ROI', ylabel = 'Company',
                       xlabel = 'ROI', legend = False)
# annotate
ax.bar_label(ax.containers[0], label_type = 'edge')

# pad the spacing between the number and edge of the figure
ax.margins(y = 0.1)

# show the visual
plt.show()

# %% [markdown]
# ### Observation
# - We can observe that 1047 Games has an ROI of 1475% on the top 10 unicorn companies by their return on investment, while 4Paradigm with 100% is at the lowest.

# %%
# Bottom 5 Companies by ROI
bot5_loc = Unicorn['ROI'].groupby(Unicorn['Company']).sum().tail(5).sort_values(ascending = False)
bot5_loc
# Out:
# Company
# reddit          900.00
# impact.com      666.28
# o9 Solutions    619.42
# solarisBank     396.28
# wefox           226.44
# Name: ROI, dtype: float64

# %%
# visualize the 5 bottom companies by ROI
# Bottom 5 Companies by ROI
bot5_loc = Unicorn['ROI'].groupby(Unicorn['Company']).sum().tail(5).sort_values(ascending=False)

# Create a pie chart
explode = (0.0, 0, 0, 0, 0)
plt.pie(bot5_loc.values, labels=bot5_loc.index, explode=explode, shadow=False, startangle=140)
plt.title('Bottom 5 Unicorn Companies by ROI')
plt.show()

# %% [markdown]
# ### Observation
# - We can observe that Wefox Company is at the least bottom of Unicorn companies by ROI with a percentage of 226.44.
# - The percentage is not showing in the chart because the ROI is already in percentage.

# %%
# Top 10 Unicorn Companies with highest Valuation
company_wise_Valuation = Unicorn.sort_values(by="Valuation", ascending=False)
company_wise_Valuation.head(10)
# Out:
#         Company     Valuation Date Joined  \
# 0     Bytedance  1.800000e+11  2017-04-07
# 1        SpaceX  1.000000e+11  2012-12-01
# 2         SHEIN  1.000000e+11  2018-07-03
# 3        Stripe  9.500000e+10  2014-01-23
# 4        Klarna  4.600000e+10  2011-12-12
# 5         Canva  4.000000e+10  2018-01-08
# 6  Checkout.com  4.000000e+10  2019-05-02
# 7     Instacart  3.900000e+10  2014-12-30
# 8     JUUL Labs  3.800000e+10  2017-12-20
# 9    Databricks  3.800000e+10  2019-02-05
#
#                               Industry           City         Country  \
# 0              Artificial Intelligence        Beijing           China
# 1                                Other      Hawthorne   United States
# 2      E-commerce & direct-to-consumer       Shenzhen           China
# 3                              Fintech  San Francisco   United States
# 4                              Fintech      Stockholm          Sweden
# 5         Internet software & services    Surry Hills       Australia
# ...

# %%
# The 5 lowest Unicorn Companies by Valuation
company_wise_Valuation = Unicorn.sort_values(by="Valuation", ascending=False)
company_wise_Valuation.tail(5)
# Out:
#                   Company     Valuation Date Joined  \
# 754        Kuaikan Manhua  1.000000e+09  2017-12-01
# 753   Incode Technologies  1.000000e+09  2021-12-07
# 752      Honor Technology  1.000000e+09  2021-10-05
# 751              Flipdish  1.000000e+09  2022-01-13
# 1073                Zwift  1.000000e+09  2020-09-16
#
#                              Industry           City        Country  \
# 754      Internet software & services        Beijing          China
# 753                     Cybersecurity  San Francisco  United States
# 752      Internet software & services  San Francisco  United States
# 751      Internet software & services         Dublin        Ireland
# 1073  E-commerce & direct-to-consumer     Long Beach  United States
#
#           Continent  Year Founded      Funding  \
# 754            Asia          2014  594000000.0
# 753   North America          2015  257000000.0
# 752   North America          2014  325000000.0
# ...

# %%
# Top 10 Unicorn Companies with highest the ROI
Company_wise_ROI = Unicorn.sort_values(by="ROI", ascending=False)
Company_wise_ROI.head(10)
# Out:
#                   Company     Valuation Date Joined  \
# 189  Otto Bock HealthCare  4.000000e+09  2017-06-24
# 239                Zapier  4.000000e+09  2021-01-14
# 61                 Dunamu  9.000000e+09  2021-07-22
# 792             Workhuman  1.000000e+09  2020-06-23
# 361                  CFGI  2.000000e+09  2021-09-15
# 743                Manner  1.000000e+09  2020-12-24
# 72        DJI Innovations  8.000000e+09  2015-01-23
# 760           GalaxySpace  1.000000e+09  2020-11-17
# 5                   Canva  4.000000e+10  2018-01-08
# 368            Il Makiage  2.000000e+09  2022-01-10
#
#                             Industry         City        Country  \
# 189                           Health   Duderstadt        Germany
# 239     Internet software & services    Sunnyvale  United States
# 61                           Fintech        Seoul    South Korea
# 792     Internet software & services       Dublin        Ireland
# ...

# %%
# visualize the bar chart
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick 
import pandas as pd

# Get the top 10 Unicorn Companies by ROI
top_10 = Company_wise_ROI[['Company', 'ROI']].head(10)

# Plot the bar chart
ax = top_10.plot.bar(x='Company', y='ROI', figsize=(10, 6))
ax.set_title('Top 10 Unicorn Companies with Highest ROI', fontsize=16, fontweight='bold')
ax.set_xlabel('Company', fontsize=14)
ax.set_ylabel('ROI', fontsize=14)
plt.show()

# %%
# Bottom 25 Unicorn Companies with lowest the ROI
Company_wise_ROI = Unicorn.sort_values(by="ROI", ascending=False)
Company_wise_ROI.tail(25)
# Out:
#               Company     Valuation Date Joined  \
# 668        Forte Labs  1.000000e+09  2021-05-12
# 658   Miaoshou Doctor  1.000000e+09  2019-06-27
# 1070      Zhuan Zhuan  1.000000e+09  2017-04-18
# 852        Leap Motor  1.000000e+09  2018-11-20
# 1014          SaltPay  1.000000e+09  2021-04-09
# 641             SumUp  1.000000e+09  2019-07-16
# 972           Momenta  1.000000e+09  2018-10-17
# 632               OVH  1.000000e+09  2016-08-15
# 577        Magic Leap  2.000000e+09  2014-10-21
# 640          Snapdeal  1.000000e+09  2014-05-21
# 1010  REEF Technology  1.000000e+09  2018-12-10
# 657   Hello TransTech  1.000000e+09  2018-06-01
# 615              Fair  1.000000e+09  2018-12-20
# 215            SSENSE  4.000000e+09  2021-06-08
# 424           Uplight  2.000000e+09  2021-03-03
# 567               ISN  2.000000e+09  2020-12-17
# 639        SITECH DEV  1.000000e+09  2019-05-16
# 651          Xiaobing  1.000000e+09  2021-07-12
# ...

# %% [markdown]
# ## Observation
# - Companies with the lowest ROI have NaN values, negative values which means these companies ran at losses, and the Zero(0) values i.e. companies without any return on investment.

# %%
# The only unicorn company with the lowest number of ROI
# Find company with lowest ROI
# Get row with lowest ROI
lowest_ROI_row = Unicorn.loc[Unicorn['ROI'].idxmin()]

# Get company with lowest ROI, returning all columns
lowest_ROI_company = Unicorn.loc[lowest_ROI_row.name]

# Print company with lowest ROI
print(f"The company with the lowest ROI is:\n{lowest_ROI_company}")
# Out:
# The company with the lowest ROI is:
# Company                                                          Fair
# Valuation                                                1000000000.0
# Date Joined                                       2018-12-20 00:00:00
# Industry                                        Auto & transportation
# City                                                     Santa Monica
# Country                                                 United States
# Continent                                               North America
# Year Founded                                                     2016
# Funding                                                  2000000000.0
# Select Investors    CreditEase Fintech Investment Fund, BMW i Vent...
# ROI                                                             -50.0
# Name: 615, dtype: object

# %%
# Which investors have funded the most?
# select investors by highest funding
company_wise_Funding = Unicorn.sort_values(by="Funding", ascending=False)
company_wise_Funding.head(10)
# Out:
#                Company     Valuation Date Joined  \
# 8            JUUL Labs  3.800000e+10  2017-12-20
# 0            Bytedance  1.800000e+11  2017-04-07
# 1               SpaceX  1.000000e+11  2012-12-01
# 11          Epic Games  3.200000e+10  2018-10-26
# 43       Global Switch  1.100000e+10  2016-12-22
# 38  Xingsheng Selected  1.200000e+10  2020-07-22
# 16         J&T Express  2.000000e+10  2021-04-07
# 41              Swiggy  1.100000e+10  2018-06-21
# 19           Yuanfudao  1.700000e+10  2017-05-31
# 30           Northvolt  1.200000e+10  2019-06-12
#
#                                Industry           City         Country  \
# 8                     Consumer & retail  San Francisco   United States
# 0               Artificial Intelligence        Beijing           China
# 1                                 Other      Hawthorne   United States
# 11                                Other           Cary   United States
# ...

# %%
# visualize using horizontal bar chart

# Create a new dataframe with the top 10 investors by funding
top_investors = company_wise_Funding[['Select Investors', 'Funding']].head(10)

# Convert the funding values to billions or millions
top_investors['Funding'] = top_investors['Funding'].apply(lambda x: x / 1000000000 if x >= 1000000000 else x / 1000000)

# Plot the horizontal bar chart
ax = top_investors.plot.barh(x='Select Investors', y='Funding', figsize=(10, 6), color='#008fd5')
ax.set_title('Top Unicorn Investors by Funding', fontsize=16, fontweight='bold')
ax.set_xlabel('Funding (Billions or Millions)', fontsize=14)
ax.set_ylabel('Select Investors', fontsize=14)
plt.show()

# %% [markdown]
# ### Observation
# #### The Top Investor that funded the more is 'TIGER GLOBAL MANAGEMENT'

# %%
# # Which investors have not funded?
# select investors by No funding
company_wise_Funding = Unicorn.sort_values(by="Funding", ascending=False)
company_wise_Funding.tail(10)
# Out:
#               Company     Valuation Date Joined  \
# 567               ISN  2.000000e+09  2020-12-17
# 639        SITECH DEV  1.000000e+09  2019-05-16
# 651          Xiaobing  1.000000e+09  2021-07-12
# 717            Veepee  1.000000e+09  2007-07-02
# 733         DistroKid  1.000000e+09  2021-08-16
# 866          Assembly  1.000000e+09  2021-09-21
# 890      Carson Group  1.000000e+09  2021-07-14
# 945   Iodine Software  1.000000e+09  2021-12-01
# 947      Kendra Scott  1.000000e+09  2016-12-21
# 1002           Poizon  1.000000e+09  2019-04-29
#
#                                  Industry                   City  \
# 567   Supply chain, logistics, & delivery                 Dallas
# 639                                 Other                Guiyang
# 651                               Fintech                Beijing
# 717       E-commerce & direct-to-consumer  La Plaine Saint-Denis
# 733          Internet software & services               New York
# ...

# %%
# check investors with low funding
bot_loc = Unicorn['Funding'].groupby(Unicorn['Select Investors']).sum().tail(10).sort_values(ascending = False)
bot_loc
# Out:
# Select Investors
# index Ventures, DST Global, Ribbit Capital                                  2.000000e+09
# Zeev Ventures, Ribbit Capital, TLV Partners                                 8.810000e+08
# btov Partners, Geely, Intel Capital                                         5.990000e+08
# next47, MaC Venture Capital, FinVC                                          5.660000e+08
# Zheshang Venture Capital, GP Capital, Western Capital Management            5.170000e+08
# e.ventures, Bain Capital Ventures, Greycroft                                5.070000e+08
# Zhangjiang Haocheng Venture Capital, Walden International, Intel Capital    2.980000e+08
# Zeev Ventures, Menlo Ventures,Crosslink Capital                             2.190000e+08
# Zeev Ventures, Group11, Chicago Ventures                                    2.100000e+08
# next47, First Round Capital, Sequoia Capital                                1.390000e+08
# Name: Funding, dtype: float64

# %%
import squarify
# !pip install squarify

# %%
# Investors with low Funding
bot_loc = Unicorn['Funding'].groupby(Unicorn['Select Investors']).sum().tail(10).sort_values(ascending = False)

# filter out zero values
bot_loc = bot_loc[bot_loc > 0]

# create a new figure with a size of (12, 12)
plt.figure(figsize=(12, 12))

# generate the tree chart
squarify.plot(sizes=bot_loc.values, label=bot_loc.index, alpha=0.8)

# add labels and title
plt.axis('off')
plt.title('Investors with low funding')

# show the chart
plt.show()

# %% [markdown]
# ## Observation
# - Observe that next47, First Round Capital, Sequoia Capital are the least Investors.
# - Followed by Zeev Ventures, Group11, Chicago Ventures.

# %%
# Countries with the most Unicorn Companies
company_wise_Country = Unicorn.sort_values(by="Country", ascending=False)
company_wise_Country.head(20)
# Out:
#              Company     Valuation Date Joined  \
# 492             MoMo  2.000000e+09  2021-12-10
# 349        Sky Mavis  3.000000e+09  2021-10-04
# 537             Rokt  2.000000e+09  2021-12-16
# 579  Modern Treasury  2.000000e+09  2021-10-06
# 565             Hive  2.000000e+09  2021-04-21
# 567              ISN  2.000000e+09  2020-12-17
# 568         Iterable  2.000000e+09  2021-06-15
# 569           Kajabi  2.000000e+09  2021-05-04
# 570           Kaseya  2.000000e+09  2019-03-27
# 574              LTK  2.000000e+09  2021-11-22
# 577       Magic Leap  2.000000e+09  2014-10-21
# 578   Misfits Market  2.000000e+09  2021-04-21
# 580            MURAL  2.000000e+09  2021-07-20
# 561          Everlaw  2.000000e+09  2020-03-10
# 582            Neo4j  2.000000e+09  2021-06-17
# 583          Netlify  2.000000e+09  2021-11-17
# 586             Pipe  2.000000e+09  2021-05-19
# 588            Quora  2.000000e+09  2017-04-21
# 589       Redis Labs  2.000000e+09  2020-08-25
# ...

# %%
# visualize number of Unicorns by Country

# Create bar chart of the number of unicorns by country
ax = Unicorn.Country.value_counts().plot.bar(figsize=(16, 10), color='#008fd5')
ax.set_title('Number of Unicorns by Country', fontsize=16, fontweight='bold')
ax.set_xlabel('Country', fontsize=14)
ax.set_ylabel('Number of counts', fontsize=14)

# Set the x-axis tick positions and labels
tick_positions = range(len(Unicorn.Country.value_counts()))
tick_labels = Unicorn.Country.value_counts().index
ax.set_xticks(tick_positions)
ax.set_xticklabels(tick_labels, rotation=45, ha='right')

plt.show()

# %% [markdown]
# # Observation
# - From the above, 'UNITED STATES' has the highest number of Unicorn Companies.
# - Followed by 'CHINA'.

# %%
# Count number of Industies 
Unicorn.Industry.value_counts()
# Out:
# Fintech                                224
# Internet software & services           205
# E-commerce & direct-to-consumer        111
# Artificial Intelligence                 84
# Health                                  74
# Other                                   58
# Supply chain, logistics, & delivery     57
# Cybersecurity                           50
# Data management & analytics             41
# Mobile & telecommunications             38
# Hardware                                34
# Auto & transportation                   31
# Edtech                                  28
# Consumer & retail                       25
# Travel                                  14
# Name: Industry, dtype: int64

# %%
# Top industries by Company presence
top5_loc = Unicorn.Industry.value_counts().head(5).sort_values(ascending = False)
top5_loc
# Out:
# Fintech                            224
# Internet software & services       205
# E-commerce & direct-to-consumer    111
# Artificial Intelligence             84
# Health                              74
# Name: Industry, dtype: int64

# %%
# using donut chart to visualize the Top 5 industries
import matplotlib.pyplot as plt

# Get the top 5 industries in the unicorn
top5_loc = Unicorn['Industry'].value_counts().nlargest(5)

# Set the explode values for the pie chart
explode = (0.0, 0, 0, 0, 0)

# Create a pie chart of the top 5 industries
plt.figure(figsize=(10, 8))
plt.pie(top5_loc, labels=top5_loc.index, autopct='%1.1f%%', pctdistance=0.85, explode=explode)

# Draw a circle in the center to make it a donut chart
centre_circle = plt.Circle((0, 0), 0.50, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Add a title to the chart
plt.title('Top 5 Industries in the Unicorn', fontsize=16, fontweight='bold')

plt.show()

# %% [markdown]
# #### Observation
# - Fintech is at the top  followed by Internet Software & Services.

# %%
# Bottom 5 industries by Company presence
bot5_loc = Unicorn.Industry.value_counts().tail(5).sort_values(ascending = False)
bot5_loc
# Out:
# Hardware                 34
# Auto & transportation    31
# Edtech                   28
# Consumer & retail        25
# Travel                   14
# Name: Industry, dtype: int64

# %%
# visualize a 2D pie for bottom 5 industries 
# Sort the data by industry and select the bottom 5 industries
bot5_industries = Unicorn.groupby('Industry').size().sort_values().head(5)

# Create a 2D pie chart
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
explode = (0.0, 0, 0, 0, 0)
ax.pie(bot5_industries.values, labels=bot5_industries.index, colors=colors,
       autopct='%1.1f%%', startangle=90, explode=explode)
ax.set_title('Bottom 5 Industries in the Unicorn')

plt.show()

# %% [markdown]
# ## Observation
# - We can observe that the least industry is TRAVEL.
# - This is followed by CONSUMER and RETAIL.

# %%
# Count the number of cities
Unicorn.City.value_counts()
# Out:
# San Francisco    152
# New York         103
# Beijing           63
# Shanghai          44
# London            34
#                 ...
# Santa Barbara      1
# Altrincham         1
# Northbrook         1
# Cincinnati         1
# Milpitas           1
# Name: City, Length: 257, dtype: int64

# %%
top_loc = Unicorn['Valuation'].groupby(Unicorn['City']).sum().head(10).sort_values(ascending = False)
top_loc
# Out:
# City
# Amsterdam     1.900000e+10
# Atlanta       1.800000e+10
# Alameda       3.000000e+09
# Aarhus        2.000000e+09
# Aberdeen      2.000000e+09
# Altrincham    2.000000e+09
# Alexandria    1.000000e+09
# Ambler        1.000000e+09
# Andheri       1.000000e+09
# Arlington     1.000000e+09
# Name: Valuation, dtype: float64

# %%
# Top 10 cities in the unicorn 
top10_loc = Unicorn.City.value_counts().head(10).sort_values(ascending = False)
top10_loc
# Out:
# San Francisco    152
# New York         103
# Beijing           63
# Shanghai          44
# London            34
# Bengaluru         29
# Shenzhen          19
# Paris             19
# Palo Alto         18
# Berlin            17
# Name: City, dtype: int64

# %%
# visualize the bar chart
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick 
import pandas as pd

# Get the top 10 cities
top10_loc = Unicorn.City.value_counts().head(10).sort_values(ascending = False)

# Plot the bar chart
ax = top10_loc.plot.bar(x='top10_loc.index', y='top1p_loc.values', figsize=(10, 6))
ax.set_title('Top 10 Unicorn Cities', fontsize=16, fontweight='bold')
ax.set_xlabel('City', fontsize=14)
ax.set_ylabel('Count', fontsize=14)
plt.show()

# %% [markdown]
# # Observe
# - that San francisco has the highest number of unicorn presence with a count of 152 , followed by New York at 103 counts.

# %%
# view distribution of ROI by Industries

# Create a new figure with a larger size
plt.figure(figsize = (20, 10))

# Load data into a DataFrame
data = Unicorn

# Create a histogram of ROI by industry with red bars
plt.hist(data['Industry'], bins=20, alpha=0.5, label='ROI', color='red')

# Set the x-axis label and title
plt.xlabel('Industry')
plt.ylabel('ROI')
plt.title('Distribution of ROI by Industries')

# Show the legend and plot the chart
plt.legend()

# Adjust the x-axis label orientation
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# ### Observation
# - The Unicorn Industry with the highest return on investment is the FINTECH industry.
# - Travel Industry has the the least ROI.

# %%
# plot a pivot table
continent_loc.plot.bar(figsize = (22, 8))
plt.ticklabel_format(style = 'plain', axis = 'y')
plt.title('The Continent by Industry with the highest Funding')
plt.show()

# %% [markdown]
# ### Observation
# - we can observe that the continent with the highest funding is NORTH AMERICA.
# - This is followed by ASIA.
# - The lowest funded continent is OCEANIA.

# %%
# Group by 'Industry' and 'City' columns and count number of occurrences
industry_city_counts = Unicorn.groupby(['Industry', 'City']).size().reset_index(name='Count')

# Group by 'Industry' column and get city with lowest count for each industry
bot_cities = industry_city_counts.loc[industry_city_counts.groupby('Industry')['Count'].idxmin()]

# Count number of cities for each industry and select bottom industries
bot_industries = bot_cities.groupby('Industry')['Count'].sum().nlargest(30)

# Get top cities for bottom industries and sort in descending order
bot_cities_bot_industries = bot_cities[bot_cities['Industry'].isin(bot_industries.index)].sort_values(['Industry', 'Count'], ascending=[False, False])

# Print bottom cities for bottom industries in descending order
print(f"Bottom cities for bottom industries in descending order:\n{bot_cities_bot_industries}")
# Out:
# Bottom cities for bottom industries in descending order:
#                                 Industry        City  Count
# 541                               Travel   Barcelona      1
# 503  Supply chain, logistics, & delivery     Atlanta      1
# 454                                Other     Alameda      1
# 431          Mobile & telecommunications   Amsterdam      1
# 352         Internet software & services      Ambler      1
# 313                               Health     Beijing      1
# 290                             Hardware   Amsterdam      1
# 208                              Fintech      Aarhus      1
# 194                               Edtech     Andheri      1
# 134      E-commerce & direct-to-consumer  Alexandria      1
# 102          Data management & analytics  Altrincham      1
# 73                         Cybersecurity  Burlington      1
# 57                     Consumer & retail    Aberdeen      1
# 39                 Auto & transportation    Bruchsal      1
# ...

# %%
# The Cities with most Industry Hubs
# Group by 'City' column and count number of occurrences
city_counts = Unicorn.groupby('City').size().reset_index(name='Count')

# Get top cities and sort in descending order
top_cities = city_counts.sort_values('Count', ascending=False).reset_index(drop=True).head(30)

# Get top industries for top cities and sort in descending order
top_industries_top_cities = Unicorn[Unicorn['City'].isin(top_cities['City'].tolist())].groupby(['City', 'Industry']).size().reset_index(name='Count').sort_values(['City', 'Count'], ascending=[True, False])

# Print top cities for all industries
print(f"Cities with most industry hubs:\n{top_cities[['City', 'Count']]}")
# Out:
# Cities with most industry hubs:
#              City  Count
# 0   San Francisco    152
# 1        New York    103
# 2         Beijing     63
# 3        Shanghai     44
# 4          London     34
# 5       Bengaluru     29
# 6           Paris     19
# 7        Shenzhen     19
# 8       Palo Alto     18
# 9          Berlin     17
# 10         Boston     16
# 11   Unidentified     16
# 12        Chicago     16
# 13  Mountain View     16
# 14       Hangzhou     16
# 15       Tel Aviv     11
# 16      San Mateo     11
# 17      Sao Paulo     11
# 18   Redwood City     10
# 19          Seoul     10
# 20         Austin      8
# 21        Seattle      8
# 22         Mumbai      8
# 23    Los Angeles      8
# 24      Sunnyvale      7
# 25       San Jose      7
# 26        Gurgaon      7
# 27      Cambridge      7
# 28        Atlanta      7
# 29      San Diego      6

# %% [markdown]
# ## Observation
# - Observe from the above that SAN FRANCISCO city in the United States is with the Lead in the Industry Hub.
# - NEW YORK is next, then Beijing  and London.

# %%
# The Cities with most Industry Hubs
# Group by 'City' column and count number of occurrences
city_counts = Unicorn.groupby('City').size().reset_index(name='Count')

# Get top cities and sort in descending order
bot_cities = city_counts.sort_values('Count', ascending=False).reset_index(drop=True).tail(30)

# Get top industries for bottom cities and sort in descending order
bot_industries_bot_cities = Unicorn[Unicorn['City'].isin(bot_cities['City'].tolist())].groupby(['City', 'Industry']).size().reset_index(name='Count').sort_values(['City', 'Count'], ascending=[True, False])

# Print bottom cities for all industries
print(f"Cities with the least industry hubs:\n{bot_cities[['City', 'Count']]}")
# Out:
# Cities with the least industry hubs:
#                  City  Count
# 227    Marina del Rey      1
# 228           Midrand      1
# 229             Milan      1
# 230          Milpitas      1
# 231       Mississauga      1
# 232          Kirkland      1
# 233           Jiangsu      1
# 234       Jersey City      1
# 235           Hayward      1
# 236         Fort Mill      1
# 237       Foster City      1
# 238        Framingham      1
# 239             Ghent      1
# 240        Giv'atayim      1
# 241            Goleta      1
# 242           Guiyang      1
# 243          Hamilton      1
# 244           Hanover      1
# 245             Hefei      1
# 246           Jeju-do      1
# 247           Herndon      1
# 248          Herzliya      1
# 249             Hunan      1
# 250         Hyderabad      1
# 251         Inglewood      1
# 252            Irving      1
# 253          Islandia      1
# 254      Jacksonville      1
# 255            Jaipur      1
# 256  Lerma de Villada      1

# %%
# How long does it take for Companies to become a Unicorn
# Convert 'Date Joined' to year only
Unicorn['Year Joined'] = pd.DatetimeIndex(Unicorn['Date Joined']).year

# Calculate years to become a unicorn
Unicorn['Years to Unicorn'] = Unicorn['Year Joined'] - Unicorn['Year Founded']

# Print results
print(f"Years to become a unicorn:\n{Unicorn[['Company', 'Year Founded', 'Date Joined', 'Years to Unicorn']]}")

# Add 'Years to Unicorn' column to 'Unicorn' DataFrame
Unicorn = Unicorn.assign(**{'Years to Unicorn': Unicorn['Years to Unicorn']})

# Print updated 'Unicorn' DataFrame
print(f"\nUpdated 'Unicorn' DataFrame:\n{Unicorn}")
# Out:
# Years to become a unicorn:
#           Company  Year Founded Date Joined  Years to Unicorn
# 0       Bytedance          2012  2017-04-07                 5
# 1          SpaceX          2002  2012-12-01                10
# 2           SHEIN          2008  2018-07-03                10
# 3          Stripe          2010  2014-01-23                 4
# 4          Klarna          2005  2011-12-12                 6
# ...           ...           ...         ...               ...
# 1069     Zhaogang          2012  2017-06-29                 5
# 1070  Zhuan Zhuan          2015  2017-04-18                 2
# 1071     Zihaiguo          2018  2021-05-06                 3
# 1072         Zopa          2005  2021-10-19                16
# 1073        Zwift          2014  2020-09-16                 6
#
# [1074 rows x 4 columns]
#
# Updated 'Unicorn' DataFrame:
#           Company     Valuation Date Joined                         Industry  \
# ...

# %%
Unicorn.head()
# Out:
#      Company     Valuation Date Joined                         Industry  \
# 0  Bytedance  1.800000e+11  2017-04-07          Artificial Intelligence
# 1     SpaceX  1.000000e+11  2012-12-01                            Other
# 2      SHEIN  1.000000e+11  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe  9.500000e+10  2014-01-23                          Fintech
# 4     Klarna  4.600000e+10  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded       Funding  \
# 0        Beijing          China           Asia          2012  8.000000e+09
# 1      Hawthorne  United States  North America          2002  7.000000e+09
# 2       Shenzhen          China           Asia          2008  2.000000e+09
# 3  San Francisco  United States  North America          2010  2.000000e+09
# 4      Stockholm         Sweden         Europe          2005  4.000000e+09
#
#                                     Select Investors      ROI  Year Joined  \
# ...

# %%
# To see an overview of companies and years to unicorn
# List Companies with the highest years to become unicorn
max_loc = Unicorn['Years to Unicorn'].groupby(Unicorn['Company']).max().sort_values(ascending = False)
max_loc
# Out:
# Company
# Otto Bock HealthCare          98
# Five Star Business Finance    37
# Promasidor Holdings           37
# Thirty Madison                28
# Radius Payment Solutions      27
#                               ..
# Mensa Brands                   0
# Avant                          0
# candy.com                      0
# Jokr                           0
# Yidian Zixun                  -4
# Name: Years to Unicorn, Length: 1073, dtype: int64

# %% [markdown]
# ## Observation
# - It took a whooping 98years for 'OTTO BOCK HEALTHCARE' company to become a UNICORN COMPANY.
# - It took 37years each for 'FIVE STAR BUSINESS FINANCE' and 'PROMASIDOR HOLDINGS' to become a UNICORN COMPANY.
# - 'THIRTY MADISON' took 28years, and 'RADIUS PAYMENT SOLUTIONS' took 27yrs to join the league of Unicorn Companies.

# %%
# List Companies with the lowest years to become unicorn
min_loc = Unicorn['Years to Unicorn'].groupby(Unicorn['Company']).min().sort_values(ascending = True)
min_loc
# Out:
# Company
# Yidian Zixun                  -4
# Playco                         0
# Mensa Brands                   0
# Avant                          0
# ClickHouse                     0
#                               ..
# Radius Payment Solutions      27
# Thirty Madison                28
# Five Star Business Finance    37
# Promasidor Holdings           37
# Otto Bock HealthCare          98
# Name: Years to Unicorn, Length: 1073, dtype: int64

# %%
# check rows where years to unicorn is 1
Unicorn[Unicorn['Years to Unicorn'] == 1]
# Out:
#                     Company     Valuation Date Joined  \
# 26           Devoted Health  1.300000e+10  2018-10-16
# 33                     Brex  1.200000e+10  2018-10-05
# 52                Chehaoduo  1.000000e+10  2016-03-12
# 78                    Hopin  8.000000e+09  2020-11-10
# 94                 Scale AI  7.000000e+09  2019-08-05
# 102   Black Unicorn Factory  6.000000e+09  2021-05-20
# 127                     Wiz  6.000000e+09  2021-03-17
# 151                Cerebral  5.000000e+09  2021-06-10
# 226               Clubhouse  4.000000e+09  2021-01-24
# 238               Yuga Labs  4.000000e+09  2022-03-22
# 317                Gorillas  3.000000e+09  2021-03-25
# 384                 SellerX  2.000000e+09  2021-12-09
# 391                 Airbyte  2.000000e+09  2021-12-17
# 414                  Pacaso  2.000000e+09  2021-03-24
# 468        Biren Technology  2.000000e+09  2020-08-18
# 491                  Uptake  2.000000e+09  2015-10-27
# ...

# %% [markdown]
# ### Observation
# - As we can see from above, the Return on Investment of theses companies that joined the Unicorns within a year are high and consistent, with valuation as high as 13billion dollars.
# - Likewise, most of them have more than two(2) Investors.
# - Though XIAOBING is without Funding and ROI but its Valuation is at $1billion, it must have joined the Unicorn Companies when its business was still booming and probably had enough funds, but due to mismanagement, fell so quickly that it cannot account for any fund to itself.

# %%
# check rows where years to unicorn is high
Unicorn[Unicorn['Years to Unicorn'] == 98]
# Out:
#                   Company     Valuation Date Joined Industry        City  \
# 189  Otto Bock HealthCare  4.000000e+09  2017-06-24   Health  Duderstadt
#
#      Country Continent  Year Founded  Funding Select Investors  ROI  \
# 189  Germany    Europe          1919      0.0     EQT Partners  inf
#
#      Year Joined  Years to Unicorn
# 189         2017                98

# %%
# check rows where years to unicorn is high
Unicorn[Unicorn['Years to Unicorn'] == 37]
# Out:
#                         Company     Valuation Date Joined           Industry  \
# 373         Promasidor Holdings  2.000000e+09  2016-11-08  Consumer & retail
# 699  Five Star Business Finance  1.000000e+09  2021-03-26              Other
#
#           City       Country Continent  Year Founded      Funding  \
# 373  Bryanston  South Africa      Asia          1979  556000000.0
# 699    Chennai         India      Asia          1984  456000000.0
#
#                                       Select Investors     ROI  Year Joined  \
# 373                                     IFC, Ajinomoto  259.71         2016
# 699  Sequoia Capital India, Tiger Global Management...  119.30         2021
#
#      Years to Unicorn
# 373                37
# 699                37

# %%
# check rows where years to unicorn is low
Unicorn[Unicorn['Years to Unicorn'] == 0]
# Out:
#                     Company     Valuation Date Joined  \
# 161   Ola Electric Mobility  5.000000e+09  2019-07-02
# 314              Flink Food  3.000000e+09  2021-12-01
# 396               candy.com  2.000000e+09  2021-10-21
# 546                   Avant  2.000000e+09  2012-12-17
# 554              ClickHouse  2.000000e+09  2021-10-28
# 775                    Jokr  1.000000e+09  2021-12-02
# 822              GlobalBees  1.000000e+09  2021-12-28
# 967            Mensa Brands  1.000000e+09  2021-11-16
# 1001                 Playco  1.000000e+09  2020-09-21
#
#                              Industry            City        Country  \
# 161             Auto & transportation       Bengaluru          India
# 314   E-commerce & direct-to-consumer          Berlin        Germany
# 396                           Fintech        New York  United States
# 546           Artificial Intelligence         Chicago  United States
# 554       Data management & analytics  Portola Valley  United States
# ...

# %%
# check rows where years to unicorn is low
Unicorn[Unicorn['Years to Unicorn'] == -4]
# Out:
#           Company     Valuation Date Joined                     Industry  \
# 714  Yidian Zixun  1.000000e+09  2017-10-17  Mobile & telecommunications
#
#         City Country Continent  Year Founded      Funding  \
# 714  Beijing   China      Asia          2021  151000000.0
#
#                                    Select Investors     ROI  Year Joined  \
# 714  Phoenix New Media, Tianjin Haihe Industry Fund  562.25         2017
#
#      Years to Unicorn
# 714                -4

# %%
# check for minimum date joined to have an idea when the Unicorn became in existence
min_loc = Unicorn['Year Joined'].groupby(Unicorn['Year Founded']).min().sort_values(ascending = True)
min_loc
# Out:
# Year Founded
# 2001    2007
# 2005    2011
# 1994    2011
# 2002    2012
# 1999    2012
# 2012    2012
# 2004    2013
# 2007    2013
# 1995    2014
# 2010    2014
# 2003    2014
# 2008    2014
# 2009    2014
# 2006    2015
# 1998    2015
# 2013    2015
# 2000    2015
# 2014    2015
# 2011    2015
# 2015    2016
# 1979    2016
# 1919    2017
# 1997    2017
# 1992    2017
# 1990    2017
# 2021    2017
# 1991    2018
# 2016    2018
# 2017    2018
# 2018    2019
# 2019    2019
# 2020    2020
# 1996    2021
# 1993    2021
# 1984    2021
# Name: Year Joined, dtype: int64

# %%
#create a line plot
plt.plot(min_loc)

# add title
plt.title('A Trend in the Year founded and the year joined of unicorn companies')

plt.ylabel=('Year Joined')
plt.xlabel=('Year Founded')

# show the chart
plt.show()

# %% [markdown]
# ## Observe
# - The company founded in 1919 Otto Bock HealthCare joined the leagues of Unicorns in the year 2017.

# %%
# check for companies with their minimum date joined to have an idea when the Unicorn became in existence
min_loc = Unicorn.groupby(['Year Founded', 'Year Joined'])['Company'].min().sort_values(ascending=True)
min_loc
# Out:
# Year Founded  Year Joined
# 2017          2021             1047 Games
# 2014          2021                  1KMXC
# 2005          2021              1Password
# 2015          2018              4Paradigm
# 2013          2021              56PINGTAI
#                                  ...
# 2021          2017           Yidian Zixun
# 2005          2016                  Yiguo
# 2001          2022               eSentire
# 1998          2015            iTutorGroup
# 2005          2017                 reddit
# Name: Company, Length: 164, dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# select numerical columns
num_cols = ['Valuation', 'Funding', 'ROI']

# calculate correlation matrix
corr_matrix = Unicorn[num_cols].corr()

# visualize the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True)
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %% [markdown]
# # OVERALL RECOMMENDATIONS
# 1 - I recommend that Unicorn Companies with a high potential growth  should:
# - Keep and continue to maintain their standards, policy, staff and stakeholders while ensuring policies are in check from time to time.
# - Be more innovative, proactive and creative to be ahead of their competitors.
# - Increase their customer service and awareness in other cities within their current states and gradually to other states.
# - Work with their finance team to Control their costs and spending because growth sometimes can mean more spending.
#
#
# 2- Unicorns should diversify their Investment portfolios as part of risk management and volatility within and across different assest classes.
# - They should take advantage of asset classes different from their sectors, such as Treasury bonds.
# - They should also invest in asset classes within their industries.
# - Unicorn companies should also consider diversifying by location such as Foreign stocks and bonds.
# - They can also hire finance and risk experts or advisors to help them keep in check their investments and rebalance their portfolios regularly.
#
# 3 - Unicorn companies with experienced leadership teams
#  should continue to understand their motivations, strengths and weaknesses.
# - They should facilitate open communication, encourage employee growth and development, also give and receive performance feedbacks.
# - They should continue to reiterate good standards and policies, and be clear on their objectives and goals.
# - Encourage innovations and creativity to stay up to date and take on challenges and stay positive as well.
# - Effective management is imminent, likewise focus on their ROIs and ensuring its increase yearly.
